# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('default')
# plt.style.available

# %% [markdown]
# ## `Problem 1 to 5`:
#
# Dataset link: https://tinyurl.com/2fe6vz4u
#
# **Add a label to every axis and add a proper title for the charts. Also add proper labels if there are multiple representations.** Then, you can customize it as your wish.
#
# ### **`Problem-1:`** Draw a line plot of which, the x-axis is the "Year" and the y-axis is sum of "PM2.5" of two countries Iran and China.

# %%
df=pd.read_csv('List of most-polluted cities by particulate matter concentration - List of most-polluted cities by particulate matter concentration.csv')
df
# Out:
#      Unnamed: 0  Position      Country     City/Town  Year  PM2.5  \
# 0             0         1        India        Kanpur  2016    173
# 1             1         2        India     Faridabad  2016    172
# 2             2         3        India          Gaya  2016    149
# 3             3         4        India      Varanasi  2016    146
# 4             4         5        India         Patna  2016    144
# ..          ...       ...          ...           ...   ...    ...
# 495         495       496       Poland        Lublin  2016     27
# 496         496       497       Poland       Siedlce  2016     27
# 497         497       498       Poland     Trzebinia  2016     27
# 498         498       499  El Salvador  San Salvador  2016     27
# 499         499       500       Turkey         Sivas  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 0                >75%   319                 NaN                     2018
# 1                >75%   316                 NaN                     2018
# 2          50% -< 75%   275                 NaN                     2018
# 3                >75%   260                 NaN                     2018
# 4                >75%   266                 NaN                     2018
# ..                ...   ...                 ...                      ...
# 495              >75%    31                >75%                     2018
# 496              >75%    29                >75%                     2018
# 497              >75%    35                >75%                     2018
# 498        50% -< 75%    59                 NaN                     2018
# 499              >75%    56                >75%                     2018
#
# [500 rows x 10 columns]

# %%
df[df['Country']=='India']  # this and query function give same output.
# Out:
#      Unnamed: 0  Position Country           City/Town  Year  PM2.5  \
# 0             0         1   India              Kanpur  2016    173
# 1             1         2   India           Faridabad  2016    172
# 2             2         3   India                Gaya  2016    149
# 3             3         4   India            Varanasi  2016    146
# 4             4         5   India               Patna  2016    144
# 5             5         6   India               Delhi  2016    143
# 6             6         7   India             Lucknow  2016    138
# 8             8         9   India                Agra  2016    131
# 9             9        10   India             Gurgaon  2016    120
# 10           10        11   India         Muzaffarpur  2016    120
# 13           13        14   India              Jaipur  2016    105
# 15           15        16   India             Patiala  2016    101
# 16           16        17   India             Jodhpur  2016     98
# 32           32        33   India              Nagpur  2016     84
# 54           54        55   India             Kolkata  2016     74
# 86           86        87   India           Ahmedabad  2015     65
# 93           93        94   India              Mumbai  2016     64
# 110         110       111   India          Chandrapur  2016     60
# 152         152       153   India           Panchkula  2016     55
# 188         188       189   India                Pune  2016     50
# 201         201       202   India             Chennai  2016     49
# 238         238       239   India           Bangalore  2016     46
# 263         263       264   India           Hyderabad  2016     44
# 289         289       290   India         Navi Mumbai  2016     41
# 290         290       291   India             Udaipur  2016     41
# 294         294       295   India            Guwahati  2016     40
# 305         305       306   India             Solapur  2016     39
# 315         315       316   India            Jabalpur  2016     38
# 345         345       346   India  Thiruvananthapuram  2016     35
# 352         352       353   India               Vizag  2016     34
# 365         365       366   India              Tezpur  2016     33
# 483         483       484   India              Aizawl  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 0                >75%   319                 NaN                     2018
# 1                >75%   316                 NaN                     2018
# 2          50% -< 75%   275                 NaN                     2018
# 3                >75%   260                 NaN                     2018
# 4                >75%   266                 NaN                     2018
# 5                >75%   292                 NaN                     2018
# 6                >75%   255                 NaN                     2018
# 8                >75%   194                 NaN                     2018
# 9          50% -< 75%   124                 NaN                     2018
# 10               >75%   221                 NaN                     2018
# 13         50% -< 75%   193                 NaN                     2018
# 15                NaN   184                 NaN                     2018
# 16               >75%   180                 NaN                     2018
# 32                NaN    86                 NaN                     2018
# 54               >75%   136                 NaN                     2018
# 86         50% -< 75%   120                 NaN                     2018
# 93               >75%   104                 NaN                     2018
# 110              >75%   109                 NaN                     2018
# 152              >75%   101                 NaN                     2018
# 188              >75%    89                 NaN                     2018
# 201              >75%    80                 NaN                     2018
# 238              >75%    96          50% -< 75%                     2018
# 263              >75%    84                 NaN                     2018
# 289               NaN    67                 NaN                     2018
# 290               NaN    98                 NaN                     2018
# 294               NaN    81                 NaN                     2018
# 305              >75%    71                 NaN                     2018
# 315               NaN    79                 NaN                     2018
# 345               NaN    48                 NaN                     2018
# 352               NaN    76                 NaN                     2018
# 365               NaN    52                 NaN                     2018
# 483               NaN    44                 NaN                     2018

# %%
df.query('Country=="India"')
# Out:
#      Unnamed: 0  Position Country           City/Town  Year  PM2.5  \
# 0             0         1   India              Kanpur  2016    173
# 1             1         2   India           Faridabad  2016    172
# 2             2         3   India                Gaya  2016    149
# 3             3         4   India            Varanasi  2016    146
# 4             4         5   India               Patna  2016    144
# 5             5         6   India               Delhi  2016    143
# 6             6         7   India             Lucknow  2016    138
# 8             8         9   India                Agra  2016    131
# 9             9        10   India             Gurgaon  2016    120
# 10           10        11   India         Muzaffarpur  2016    120
# 13           13        14   India              Jaipur  2016    105
# 15           15        16   India             Patiala  2016    101
# 16           16        17   India             Jodhpur  2016     98
# 32           32        33   India              Nagpur  2016     84
# 54           54        55   India             Kolkata  2016     74
# 86           86        87   India           Ahmedabad  2015     65
# 93           93        94   India              Mumbai  2016     64
# 110         110       111   India          Chandrapur  2016     60
# 152         152       153   India           Panchkula  2016     55
# 188         188       189   India                Pune  2016     50
# 201         201       202   India             Chennai  2016     49
# 238         238       239   India           Bangalore  2016     46
# 263         263       264   India           Hyderabad  2016     44
# 289         289       290   India         Navi Mumbai  2016     41
# 290         290       291   India             Udaipur  2016     41
# 294         294       295   India            Guwahati  2016     40
# 305         305       306   India             Solapur  2016     39
# 315         315       316   India            Jabalpur  2016     38
# 345         345       346   India  Thiruvananthapuram  2016     35
# 352         352       353   India               Vizag  2016     34
# 365         365       366   India              Tezpur  2016     33
# 483         483       484   India              Aizawl  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 0                >75%   319                 NaN                     2018
# 1                >75%   316                 NaN                     2018
# 2          50% -< 75%   275                 NaN                     2018
# 3                >75%   260                 NaN                     2018
# 4                >75%   266                 NaN                     2018
# 5                >75%   292                 NaN                     2018
# 6                >75%   255                 NaN                     2018
# 8                >75%   194                 NaN                     2018
# 9          50% -< 75%   124                 NaN                     2018
# 10               >75%   221                 NaN                     2018
# 13         50% -< 75%   193                 NaN                     2018
# 15                NaN   184                 NaN                     2018
# 16               >75%   180                 NaN                     2018
# 32                NaN    86                 NaN                     2018
# 54               >75%   136                 NaN                     2018
# 86         50% -< 75%   120                 NaN                     2018
# 93               >75%   104                 NaN                     2018
# 110              >75%   109                 NaN                     2018
# 152              >75%   101                 NaN                     2018
# 188              >75%    89                 NaN                     2018
# 201              >75%    80                 NaN                     2018
# 238              >75%    96          50% -< 75%                     2018
# 263              >75%    84                 NaN                     2018
# 289               NaN    67                 NaN                     2018
# 290               NaN    98                 NaN                     2018
# 294               NaN    81                 NaN                     2018
# 305              >75%    71                 NaN                     2018
# 315               NaN    79                 NaN                     2018
# 345               NaN    48                 NaN                     2018
# 352               NaN    76                 NaN                     2018
# 365               NaN    52                 NaN                     2018
# 483               NaN    44                 NaN                     2018

# %%
df[df['Country']=='China'].groupby('Year')['PM2.5'].sum()
# Out:
# Year
# 2014     2725
# 2015      425
# 2016    11106
# Name: PM2.5, dtype: int64

# %%
x=df.query('Country=="China"').groupby('Year')['PM2.5'].sum()
x
# Out:
# Year
# 2014     2725
# 2015      425
# 2016    11106
# Name: PM2.5, dtype: int64

# %%
df[df['Country']=='Iran']
# Out:
#      Unnamed: 0  Position Country       City/Town  Year  PM2.5  \
# 83           83        84    Iran         Hamedan  2013     66
# 104         104       105    Iran            Qods  2016     61
# 126         126       127    Iran           Ahvaz  2016     58
# 144         144       145    Iran         Genaveh  2016     56
# 153         153       154    Iran        Asaluyeh  2016     55
# 189         189       190    Iran           Zabol  2016     50
# 239         239       240    Iran     Baghershahr  2016     46
# 240         240       241    Iran         Bushehr  2016     46
# 264         264       265    Iran        Dehloran  2016     44
# 265         265       266    Iran          Mehran  2016     44
# 277         277       278    Iran          Kangan  2016     42
# 306         306       307    Iran     Shahinshahr  2016     39
# 316         316       317    Iran    Shahre Ghods  2016     38
# 317         317       318    Iran        Shahryar  2016     38
# 324         324       325    Iran    Lavan Island  2016     37
# 325         325       326    Iran            Sari  2012     37
# 334         334       335    Iran         Varamin  2016     36
# 335         335       336    Iran            Yazd  2016     36
# 346         346       347    Iran            Ghom  2016     35
# 353         353       354    Iran      Ilam, Iran  2016     34
# 366         366       367    Iran     Khorramabad  2016     33
# 367         367       368    Iran        Pakdasht  2016     33
# 383         383       384    Iran          Abadan  2016     32
# 384         384       385    Iran        Asadabad  2016     32
# 385         385       386    Iran      Eslamshahr  2016     32
# 386         386       387    Iran      Kermanshah  2016     32
# 387         387       388    Iran     Savegbelagh  2016     32
# 400         400       401    Iran            Arak  2016     31
# 401         401       402    Iran         Esfahan  2014     31
# 402         402       403    Iran       Nazarabad  2016     31
# 420         420       421    Iran         Isfahan  2016     30
# 421         421       422    Iran           Karaj  2016     30
# 422         422       423    Iran         Mashhad  2016     30
# 439         439       440    Iran       Najafabad  2016     29
# 440         440       441    Iran           Yasuj  2016     29
# 461         461       462    Iran         Bojnord  2016     28
# 462         462       463    Iran  Khomeyni Shahr  2016     28
# 463         463       464    Iran       Mobarakeh  2016     28
# 464         464       465    Iran      Robatkarim  2016     28
# 465         465       466    Iran        Sanandaj  2016     28
# 466         466       467    Iran          Tehran  2016     28
# 484         484       485    Iran         Hamadan  2016     27
# 485         485       486    Iran   Pol-e Dokhtar  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 83                NaN   149                 NaN                     2018
# 104               NaN   140                 NaN                     2018
# 126               NaN   132                 NaN                     2018
# 144               NaN   129                 NaN                     2018
# 153               NaN   126                 NaN                     2018
# 189               NaN   115                 NaN                     2018
# 239               NaN   105                 NaN                     2018
# 240               NaN   105                 NaN                     2018
# 264               NaN   100                 NaN                     2018
# 265               NaN   102                 NaN                     2018
# 277               NaN    96                 NaN                     2018
# 306               NaN    89                 NaN                     2018
# 316               NaN    87                 NaN                     2018
# 317               NaN    87                 NaN                     2018
# 324               NaN    85                 NaN                     2018
# 325               NaN    90                 NaN                     2016
# 334               NaN    83                 NaN                     2018
# 335               NaN    83                 NaN                     2018
# 346               NaN    81                 NaN                     2018
# 353               NaN    79                 NaN                     2018
# 366               NaN    75                 NaN                     2018
# 367               NaN    75                 NaN                     2018
# 383               NaN    74                 NaN                     2018
# 384               NaN    73                 NaN                     2018
# 385               NaN    73                 NaN                     2018
# 386               NaN    73                 NaN                     2018
# 387               NaN    72                 NaN                     2018
# 400               NaN    71                 NaN                     2018
# 401               NaN    72                 NaN                     2018
# 402               NaN    71                 NaN                     2018
# 420               NaN    68                 NaN                     2018
# 421               NaN    68                 NaN                     2018
# 422               NaN    69                 NaN                     2018
# 439               NaN    67                 NaN                     2018
# 440               NaN    66                 NaN                     2018
# 461               NaN    64                 NaN                     2018
# 462               NaN    64                 NaN                     2018
# 463               NaN    65                 NaN                     2018
# 464               NaN    63                 NaN                     2018
# 465               NaN    64                 NaN                     2018
# 466               NaN    72                 NaN                     2018
# 484               NaN    61                 NaN                     2018
# 485               NaN    62                 NaN                     2018

# %%
df.query('Country=="Iran"')
# Out:
#      Unnamed: 0  Position Country       City/Town  Year  PM2.5  \
# 83           83        84    Iran         Hamedan  2013     66
# 104         104       105    Iran            Qods  2016     61
# 126         126       127    Iran           Ahvaz  2016     58
# 144         144       145    Iran         Genaveh  2016     56
# 153         153       154    Iran        Asaluyeh  2016     55
# 189         189       190    Iran           Zabol  2016     50
# 239         239       240    Iran     Baghershahr  2016     46
# 240         240       241    Iran         Bushehr  2016     46
# 264         264       265    Iran        Dehloran  2016     44
# 265         265       266    Iran          Mehran  2016     44
# 277         277       278    Iran          Kangan  2016     42
# 306         306       307    Iran     Shahinshahr  2016     39
# 316         316       317    Iran    Shahre Ghods  2016     38
# 317         317       318    Iran        Shahryar  2016     38
# 324         324       325    Iran    Lavan Island  2016     37
# 325         325       326    Iran            Sari  2012     37
# 334         334       335    Iran         Varamin  2016     36
# 335         335       336    Iran            Yazd  2016     36
# 346         346       347    Iran            Ghom  2016     35
# 353         353       354    Iran      Ilam, Iran  2016     34
# 366         366       367    Iran     Khorramabad  2016     33
# 367         367       368    Iran        Pakdasht  2016     33
# 383         383       384    Iran          Abadan  2016     32
# 384         384       385    Iran        Asadabad  2016     32
# 385         385       386    Iran      Eslamshahr  2016     32
# 386         386       387    Iran      Kermanshah  2016     32
# 387         387       388    Iran     Savegbelagh  2016     32
# 400         400       401    Iran            Arak  2016     31
# 401         401       402    Iran         Esfahan  2014     31
# 402         402       403    Iran       Nazarabad  2016     31
# 420         420       421    Iran         Isfahan  2016     30
# 421         421       422    Iran           Karaj  2016     30
# 422         422       423    Iran         Mashhad  2016     30
# 439         439       440    Iran       Najafabad  2016     29
# 440         440       441    Iran           Yasuj  2016     29
# 461         461       462    Iran         Bojnord  2016     28
# 462         462       463    Iran  Khomeyni Shahr  2016     28
# 463         463       464    Iran       Mobarakeh  2016     28
# 464         464       465    Iran      Robatkarim  2016     28
# 465         465       466    Iran        Sanandaj  2016     28
# 466         466       467    Iran          Tehran  2016     28
# 484         484       485    Iran         Hamadan  2016     27
# 485         485       486    Iran   Pol-e Dokhtar  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 83                NaN   149                 NaN                     2018
# 104               NaN   140                 NaN                     2018
# 126               NaN   132                 NaN                     2018
# 144               NaN   129                 NaN                     2018
# 153               NaN   126                 NaN                     2018
# 189               NaN   115                 NaN                     2018
# 239               NaN   105                 NaN                     2018
# 240               NaN   105                 NaN                     2018
# 264               NaN   100                 NaN                     2018
# 265               NaN   102                 NaN                     2018
# 277               NaN    96                 NaN                     2018
# 306               NaN    89                 NaN                     2018
# 316               NaN    87                 NaN                     2018
# 317               NaN    87                 NaN                     2018
# 324               NaN    85                 NaN                     2018
# 325               NaN    90                 NaN                     2016
# 334               NaN    83                 NaN                     2018
# 335               NaN    83                 NaN                     2018
# 346               NaN    81                 NaN                     2018
# 353               NaN    79                 NaN                     2018
# 366               NaN    75                 NaN                     2018
# 367               NaN    75                 NaN                     2018
# 383               NaN    74                 NaN                     2018
# 384               NaN    73                 NaN                     2018
# 385               NaN    73                 NaN                     2018
# 386               NaN    73                 NaN                     2018
# 387               NaN    72                 NaN                     2018
# 400               NaN    71                 NaN                     2018
# 401               NaN    72                 NaN                     2018
# 402               NaN    71                 NaN                     2018
# 420               NaN    68                 NaN                     2018
# 421               NaN    68                 NaN                     2018
# 422               NaN    69                 NaN                     2018
# 439               NaN    67                 NaN                     2018
# 440               NaN    66                 NaN                     2018
# 461               NaN    64                 NaN                     2018
# 462               NaN    64                 NaN                     2018
# 463               NaN    65                 NaN                     2018
# 464               NaN    63                 NaN                     2018
# 465               NaN    64                 NaN                     2018
# 466               NaN    72                 NaN                     2018
# 484               NaN    61                 NaN                     2018
# 485               NaN    62                 NaN                     2018

# %%
df[df['Country']=='Iran'].groupby('Year')['PM2.5'].sum()
# Out:
# Year
# 2012      37
# 2013      66
# 2014      31
# 2016    1453
# Name: PM2.5, dtype: int64

# %%
y=df.query('Country=="Iran"').groupby('Year')['PM2.5'].sum()
y
# Out:
# Year
# 2012      37
# 2013      66
# 2014      31
# 2016    1453
# Name: PM2.5, dtype: int64

# %%
plt.plot(x.index,x.values,linestyle='dashed',label='China')
plt.plot(y.index,y.values,linestyle='dashed',label='Iran')

plt.title('China Vs Iran PM2.5 over the years')
plt.xlabel('Year')
plt.ylabel('PM2.5')

plt.xticks(df['Year'].value_counts().index)

plt.legend()
plt.grid()
plt.show()

# %%
df['Year'].value_counts().index
# Out:
# Int64Index([2016, 2014, 2015, 2012, 2013, 2010, 2011, 2008, 2009, 2017], dtype='int64')

# %% [markdown]
# ### **`Problem-2:`** Draw a histogram of the  column "PM10" of which the y-axis represents the probability (see the documentation how to draw the probability).

# %%
plt.hist(df['PM10'])
plt.show()

# %% [markdown]
# ### **`Problem-3:`** Draw a scatter plot where x-axis represents "PM2.5" and y-axis represents "PM10" for two countries Poland and Chile.

# %%
poland=df.query('Country=="Poland"')
chile=df.query('Country=="Chile"')

plt.scatter(poland['PM2.5'],poland['PM10'],color='red',marker='+',label='Poland')
plt.scatter(chile['PM2.5'],chile['PM10'],color='blue',marker="*",label='chile')

plt.title('Poland vs Chile')
plt.xlabel('PM2.5')
plt.ylabel('PM10')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-4:`** Draw a pie chart of top 5 most frequent countries.

# %%
x=df['Country'].value_counts().head()
plt.pie(x,labels=x.index,autopct='%0.1f%%')
plt.show()

# %% [markdown]
# ### **`Problem-5:`** Draw a bar chart which represents the counts of top 5 most frequent countries.

# %%
x=df['Country'].value_counts().head()
plt.bar(x.index,x)
plt.show()

# %% [markdown]
# ## `Problem 6-10`
# Data Set - https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv
#
# This is a Sales data of any company in a Year.
#
#
# ### `Problem-6`
# Show a line plot of Total Profit for each month with below styling.
# * Dotted Line
# * Line Color Blue
# * Show Legend at top left
# * Circle Marker

# %%
df=pd.read_csv('company_sales_data - company_sales_data.csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
plt.plot(df['month_number'],df['total_profit'],linestyle='dotted',color='blue',label='month by month profit',marker='o')

plt.title('Company Sales Profit')
plt.xlabel('Month')
plt.ylabel('Total Profit')

plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### `Problem-7`
# Show sales of each product in march month as pie chart.
# * Show Percentage value
# * Give Title "Sales in March"
# * Explode ToothPaste with shadow

# %%
labels = df[df['month_number'] == 3].iloc[:,1:7].stack().index.get_level_values(1)
values = df[df['month_number'] == 3].iloc[:,1:7].stack().values

plt.pie(values,labels=labels,autopct='%0.1f%%',explode=[0,0,0.1,0,0,0],shadow=True)
plt.title("Sales in March")
plt.show()

# %%
df[df['month_number']==3].iloc[:,1:7].stack().values
# Out:
# array([2140, 1340, 4550, 9550, 3550, 1340], dtype=int64)

# %%
df[df['month_number']==3].iloc[:,1:7].stack().index.get_level_values(1)
# Out:
# Index(['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo',
#        'moisturizer'],
#       dtype='object')

# %% [markdown]
# ### `Problem-8` Multiline Plot of all products sales.
# * Give different styes for each products
# * Add legend at top right

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
monthlist=df['month_number'].tolist()

plt.plot(monthlist,df['facecream'],linestyle='dotted',color='orange',linewidth=3,label='facecream')
plt.plot(monthlist,df['facewash'],linestyle='dashed',label='facewash')
plt.plot(monthlist,df['toothpaste'],linestyle='dashdot',color='blue',label='toothpaste')
plt.plot(monthlist,df['bathingsoap'],marker='D',label='bathingsoap')
plt.plot(monthlist,df['shampoo'],color='red',linewidth=3,marker='o',linestyle='dotted',label='shampoo')
plt.plot(monthlist,df['moisturizer'],marker='o',label='moisturizer')


plt.legend(loc='upper right')
plt.xticks(monthlist)
plt.title('Sales data')
plt.show()

# %% [markdown]
# ### `Problem-9` Show Quarter wise Sales data for all products as multi Bar chart.

# %%
pd.to_datetime(['2020-{}-01'.format(month) for month in df['month_number']])
# Out:
# DatetimeIndex(['2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
df['date'] = pd.to_datetime(['2020-{}-01'.format(month) for month in df['month_number']])

# %%
final_df = df.groupby(df['date'].dt.quarter).sum()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13488\1499787424.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   final_df = df.groupby(df['date'].dt.quarter).sum()

# %%
final_df
# Out:
#       month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# date
# 1                6       7270      4040       14850        24850     6850
# 2               15       9760      4425       15320        24120     5320
# 3               24      10220      4300       16740        27040     6740
# 4               33       7230      5750       23000        38000     6500
#
#       moisturizer  total_units  total_profit
# date
# 1            4040        61900        619000
# 2            4425        63370        633700
# 3            4300        89090        890900
# 4            5750        97970        979700

# %%
i = -1
for col in final_df.columns[1:7]:
  plt.bar(final_df.index + i,final_df[col],width=0.15,label=col)
  i = i - 0.15

plt.xticks(final_df.index-1.4,final_df.index)
#plt.xlabel('Product')
#plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
final_df.iloc[:,1:7]
# Out:
#       facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer
# date
# 1          7270      4040       14850        24850     6850         4040
# 2          9760      4425       15320        24120     5320         4425
# 3         10220      4300       16740        27040     6740         4300
# 4          7230      5750       23000        38000     6500         5750

# %% [markdown]
# ### `Problem-10` Plot Stacked Bar chart quarter wise for each product.

# %%
all_cols = []

for col in final_df.columns[1:7]:
  if len(all_cols) == 0:
    plt.bar(final_df.index,final_df[col],label=col)
  else:
    plt.bar(final_df.index,final_df[col],bottom=sum(all_cols),label=col)
  all_cols.append(final_df[col])

plt.xticks(final_df.index - 0.02, final_df.index)
plt.legend()
plt.show()

# %%
sum(all_cols)
# Out:
# date
# 1    61900
# 2    63370
# 3    69340
# 4    86230
# dtype: int64

# %% [markdown]
# # Problem with Q.2,Q.9,Q.10

# %%
df=pd.read_csv('batsman_season_record.csv')
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(np.arange(df.shape[0])-0.2,df['2015'],width=0.2,label='2015')
plt.bar(np.arange(df.shape[0]),df['2016'],width=0.2,label='2016')
plt.bar(np.arange(df.shape[0])+0.2,df['2017'],width=0.2,label='2017')

plt.title('Batsman Runs Year Wise')
plt.xlabel('Batsman')
plt.ylabel('Runs')

plt.xticks(np.arange(df.shape[0]),df['batsman'],rotation='vertical')
plt.legend()
plt.show()

# %%
plt.bar(df['batsman'],df['2015'],label='2015')
plt.bar(df['batsman'],df['2016'],bottom=df['2015'],label='2016')
plt.bar(df['batsman'],df['2017'],bottom=(df['2015']+df['2016']),label='2017')

plt.legend()
